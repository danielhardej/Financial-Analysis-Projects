# %%
import alpha_vantage
import yfinance as yf
import yahoo_fin.stock_info as si
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as pdr
from datetime import datetime
import os

# %% [markdown]
# Test using `yahoo_fin` package

# %%
yf.pdr_override()
hist = si.get_earnings_history('msft')
 
hist[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 yf.pdr_override()
# ----> 2 hist = si.get_earnings_history('msft')
#       4 hist[0]
#
# File ~/Documents/GitHub/Financial-Analysis-Projects/.conda/lib/python3.10/site-packages/yahoo_fin/stock_info.py:838, in get_earnings_history(ticker)
#     834 url = 'https://finance.yahoo.com/calendar/earnings?symbol=' + ticker
#     836 result = _parse_earnings_json(url)
# --> 838 return result["context"]["dispatcher"]["stores"]["ScreenerResultsStore"]["results"]["rows"]
#
# TypeError: string indices must be integers

# %% [markdown]
# Nevermind. It's a pile of crap.
#
# Trying `yfinance` package instead

# %%
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'symbol': 'MSFT',
#  'twoHundredDayAverageChangePercent': 0.11863088,
#  'dividendDate': 1686182400,
#  'fiftyTwoWeekLowChangePercent': 0.33031908,
#  'averageAnalystRating': '1.9 - Buy',
#  'language': 'en-US',
#  'earningsTimestampEnd': 1682683200,
#  'regularMarketDayRange': '282.03 - 284.68',
#  'epsForward': 10.75,
#  'regularMarketDayHigh': 284.68,
#  'twoHundredDayAverageChange': 30.110794,
#  'twoHundredDayAverage': 253.8192,
#  'askSize': 10,
#  'bookValue': 24.592,
#  'fiftyTwoWeekHighChange': -19.720001,
#  'marketCap': 2134628368384,
#  'fiftyTwoWeekRange': '213.43 - 303.65',
#  'fiftyDayAverageChange': 20.822601,
#  'firstTradeDateMilliseconds': 511108200000,
#  'exchangeDataDelayedBy': 0,
#  'averageDailyVolume3Month': 31842393,
#  'trailingAnnualDividendRate': 2.6,
#  'fiftyTwoWeekLow': 213.43,
#  'regularMarketVolume': 4182589,
#  'market': 'us_market',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'messageBoardId': 'finmb_21835',
#  'priceHint': 2,
# ...

# %%
hist = msft.history(period="1mo")
hist
# Out:
#                                  Open        High         Low       Close
# Date
# 2023-03-06 00:00:00-05:00  256.429993  260.119995  255.979996  256.869995  \
# 2023-03-07 00:00:00-05:00  256.299988  257.690002  253.389999  254.149994
# 2023-03-08 00:00:00-05:00  254.039993  254.539993  250.809998  253.699997
# 2023-03-09 00:00:00-05:00  255.820007  259.559998  251.580002  252.320007
# 2023-03-10 00:00:00-05:00  251.080002  252.789993  247.600006  248.589996
# 2023-03-13 00:00:00-04:00  247.399994  257.910004  245.729996  253.919998
# 2023-03-14 00:00:00-04:00  256.750000  261.070007  255.860001  260.790009
# 2023-03-15 00:00:00-04:00  259.980011  266.480011  259.209991  265.440002
# 2023-03-16 00:00:00-04:00  265.209991  276.559998  263.279999  276.200012
# 2023-03-17 00:00:00-04:00  278.260010  283.329987  276.320007  279.429993
# 2023-03-20 00:00:00-04:00  276.980011  277.480011  269.850006  272.230011
# 2023-03-21 00:00:00-04:00  274.880005  275.000000  269.519989  273.779999
# ...

# %%
aapl = pdr.DataReader("AAPL", "av-monthly", start=datetime(2017, 2, 9), end=datetime(2017, 5, 24), api_key='REGTU7YTI3S3D5UM')

# %%
print(aapl)
# Out:
#               open    high     low   close     volume
# 2017-02-28  127.03  137.48  127.01  136.99  574968547
# 2017-03-31  137.89  144.50  137.05  143.66  562091214
# 2017-04-28  143.71  145.46  140.06  143.65  371280180

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 # get earnings for AAPL with alpha vantage
# ----> 2 import AlphaVantage.FundamentalData as av
#
# ModuleNotFoundError: No module named 'AlphaVantage'
